# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import datetime

from dateutil.parser import parse

# %%
df_path = os.path.join('..', '..', 'data', 'interim', '2_tbs_with_datetime.csv')
df = pd.read_csv(df_path, index_col = 0)
# Out:
# /Users/brycehaley/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (5,7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/brycehaley/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df
# Out:
#          trip_id      trip_start_time       trip_stop_time  \
# 0         712382  2017-01-01 00:00:00  2017-01-01 00:03:00
# 1         712383  2017-01-01 00:00:00  2017-01-01 00:05:00
# 2         712384  2017-01-01 00:05:00  2017-01-01 00:29:00
# 3         712385  2017-01-01 00:07:00  2017-01-01 00:21:00
# 4         712386  2017-01-01 00:08:00  2017-01-01 00:12:00
# ...          ...                  ...                  ...
# 1492364  2383642  2017-12-31 23:46:27  2017-12-31 23:46:53
# 1492365  2383643  2017-12-31 23:47:13  2018-01-01 00:11:00
# 1492366  2383644  2017-12-31 23:47:40  2017-12-31 23:57:49
# 1492367  2383645  2017-12-31 23:49:08  2017-12-31 23:49:34
# 1492368  2383646  2017-12-31 23:49:41  2017-12-31 23:57:41
#
#          trip_duration_seconds           from_station_id  \
# 0                        223.0                      7051
# 1                        279.0                      7143
# 2                       1394.0                      7113
# ...

# %%
path2 = os.path.join('..', '..', 'data', 'interim', '2_just_dashes.csv')
df2 = pd.read_csv(path2, index_col = 0)

# %%
df2
# Out:
#          trip_id    trip_start_time     trip_stop_time  trip_duration_seconds  \
# 0         712382      1/1/2017 0:00      1/1/2017 0:03                  223.0
# 1         712383      1/1/2017 0:00      1/1/2017 0:05                  279.0
# 2         712384      1/1/2017 0:05      1/1/2017 0:29                 1394.0
# 3         712385      1/1/2017 0:07      1/1/2017 0:21                  826.0
# 4         712386      1/1/2017 0:08      1/1/2017 0:12                  279.0
# ...          ...                ...                ...                    ...
# 1492364  2383642  12/31/17 23:46:27  12/31/17 23:46:53                   26.0
# 1492365  2383643  12/31/17 23:47:13      01/01/18 0:11                 1467.0
# 1492366  2383644  12/31/17 23:47:40  12/31/17 23:57:49                  609.0
# 1492367  2383645  12/31/17 23:49:08  12/31/17 23:49:34                   26.0
# 1492368  2383646  12/31/17 23:49:41  12/31/17 23:57:41                  480.0
#
# ...

# %%
path3 = os.path.join('..', '..', 'data', 'interim', '1_tbs_with_date_flags.csv')
df3 = pd.read_csv(path3, index_col = 0)

# %%
df3
# Out:
#          trip_id    trip_start_time     trip_stop_time  trip_duration_seconds  \
# 0         712382      1/1/2017 0:00      1/1/2017 0:03                  223.0
# 1         712383      1/1/2017 0:00      1/1/2017 0:05                  279.0
# 2         712384      1/1/2017 0:05      1/1/2017 0:29                 1394.0
# 3         712385      1/1/2017 0:07      1/1/2017 0:21                  826.0
# 4         712386      1/1/2017 0:08      1/1/2017 0:12                  279.0
# ...          ...                ...                ...                    ...
# 1492364  2383642  12/31/17 23:46:27  12/31/17 23:46:53                   26.0
# 1492365  2383643  12/31/17 23:47:13    2001-01-18 0:11                 1467.0
# 1492366  2383644  12/31/17 23:47:40  12/31/17 23:57:49                  609.0
# 1492367  2383645  12/31/17 23:49:08  12/31/17 23:49:34                   26.0
# 1492368  2383646  12/31/17 23:49:41  12/31/17 23:57:41                  480.0
#
# ...
